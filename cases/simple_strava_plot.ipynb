# %%
from strava import activity, athlete, vmplotlib
import numpy as np
from matplotlib import pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Test activity
id_mdd30 = '628508858'
mdd30 = activity.Activity(activity_id=id_mdd30)

# %%
stravaPlot = vmplotlib.SimpleStravaPlot(mdd30, title='#mdd30')
